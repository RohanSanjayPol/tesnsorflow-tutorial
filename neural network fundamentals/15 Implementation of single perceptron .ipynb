# %%
# implementing necessary libraries
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten

# %%
# generate synthetic dataset and split it
x,y=make_classification(
n_samples=1000,# 1000 samples it will generate
    n_features=2, # it has two features
    n_informative=2, # both two features are important for predicting
    n_redundant=0,# no linear combinations
    n_repeated=0, # no repetation
    n_classes=2,# it has two classes
    random_state=42 # it ensures reproducibility (it generate same dataset)
)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# standardize the dataset
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
# finding input shape
input_shape=x_train[0].shape
input_shape
# Out:
# (2,)

# %%
# building a neural network
model= Sequential([
    Dense(units=1,activation='sigmoid',input_shape=input_shape)
])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3 (12.00 B)
#  Trainable params: 3 (12.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# compile the model
model.compile(optimizer='adam',
             loss='binary_crossentropy',
             metrics=['accuracy'])

# %%
# train the model
history=model.fit(x_train,y_train,
         validation_data=(x_test,y_test),
          epochs=50,
          batch_size=16,
          #verbose=0,
         )
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8529 - loss: 0.4050 - val_accuracy: 0.8800 - val_loss: 0.3777
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8501 - loss: 0.4070 - val_accuracy: 0.8800 - val_loss: 0.3750
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8564 - loss: 0.4071 - val_accuracy: 0.8800 - val_loss: 0.3723
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8585 - loss: 0.4016 - val_accuracy: 0.8800 - val_loss: 0.3697
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8750 - loss: 0.3859 - val_accuracy: 0.8800 - val_loss: 0.3671
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8753 - loss: 0.4017 - val_accuracy: 0.8750 - val_loss: 0.3647
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8725 - loss: 0.3758 - val_accuracy: 0.8750 - val_loss: 0.3623
# Epoch 8/50
# ...

# %%
# model evaluation
loss,accuracy=model.evaluate(x_test,y_test,verbose=0)
print("test_accuracy: ",accuracy)
print("test_loss: ",loss)
# Out:
# test_accuracy:  0.8799999952316284
# test_loss:  0.38038086891174316
