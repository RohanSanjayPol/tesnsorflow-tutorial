# %% [markdown]
# #### 1. Import Libraries

# %%
# importing necessesary libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Flatten ,Dropout,MaxPooling2D

# %% [markdown]
# #### 2. prepare the data

# %%
from tensorflow.keras.datasets import mnist
(x_train,y_train),(x_test,y_test)=mnist.load_data()
x_train,x_test=x_train/225.0,x_test/255.0

# %% [markdown]
# #### 3. build the neural network

# %%
model=keras.Sequential([
   Flatten(input_shape=(28,28)),
   Dense(128,activation='relu'),
   Dense(64,activation='relu'),
   Dense(10,activation='softmax')
])
# Out:
# C:\Users\polro\anaconda3\envs\cleanenv\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# #### 4. compile the model

# %%
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %% [markdown]
# #### 5. model training

# %%
model.fit(x_train,y_train,epochs=15,validation_data=(x_test,y_test))
# Out:
# Epoch 1/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8807 - loss: 0.4108 - val_accuracy: 0.9660 - val_loss: 0.1175
# Epoch 2/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9686 - loss: 0.1046 - val_accuracy: 0.9717 - val_loss: 0.1006
# Epoch 3/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9788 - loss: 0.0693 - val_accuracy: 0.9713 - val_loss: 0.0955
# Epoch 4/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9842 - loss: 0.0497 - val_accuracy: 0.9720 - val_loss: 0.0860
# Epoch 5/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9866 - loss: 0.0400 - val_accuracy: 0.9772 - val_loss: 0.0769
# Epoch 6/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9905 - loss: 0.0294 - val_accuracy: 0.9787 - val_loss: 0.0708
# Epoch 7/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9926 - loss: 0.0236 - val_accuracy: 0.9746 - val_loss: 0.0871
# Epoch 8/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9931 - loss: 0.0213 - val_accuracy: 0.9772 - val_loss: 0.0810
# Epoch 9/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9940 - loss: 0.0187 - val_accuracy: 0.9794 - val_loss: 0.0782
# Epoch 10/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9947 - loss: 0.0157 - val_accuracy: 0.9791 - val_loss: 0.0809
# Epoch 11/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9953 - loss: 0.0128 - val_accuracy: 0.9754 - val_loss: 0.0987
# Epoch 12/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9946 - loss: 0.0174 - val_accuracy: 0.9796 - val_loss: 0.0834
# Epoch 13/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9952 - loss: 0.0131 - val_accuracy: 0.9806 - val_loss: 0.0897
# Epoch 14/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.9797 - val_loss: 0.0911
# Epoch 15/15
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9965 - loss: 0.0105 - val_accuracy: 0.9765 - val_loss: 0.1075

# %% [markdown]
# #### 6. Model Evaluation

# %%
test_loss,test_accuracy=model.evaluate(x_test,y_test)
print('test loss: ',test_loss)
print('test accuracy:',test_accuracy)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.1294
# test loss:  0.10751142352819443
# test accuracy: 0.9764999747276306
